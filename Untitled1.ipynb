# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-sohee1379/test1/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   # 1주차 과제(20.05.23)
#
#
# *   **음성** - 인공지능 성우 서비스 ‘타입캐스트’
#
#   : 타입캐스트는 전문 성우의 목소리를 활용한 인공지능 음성 생성 기술을 기반으로, 50여 개의 다양한 음성을 실시간 오디오 콘텐츠로 변환해 주는 서비스다. 텍스트로 된 문장을 입력 창에 작성한 후 성별, 연령, 콘텐츠 분위기 등에 따라 이용자가 원하는 타입의 성우를 캐스팅하여 편집하면 전문 성우가 녹음한 것과 같은 음성 파일을 간편하게 내려받을 수 있다. 개인 이용자 뿐 아니라 기업의 온라인 뉴스 채널, 교육 및 출판 관계자들에게도 큰 주목을 받았다. 관계자는 “문자를 음성으로 변환하는 TTS(Text to Speech)는 오래 전부터 사용되어 왔던 서비스지만 전문 성우의 음성을 활용해 섬세한 감정 표현, 운율을 더한 고도화된 음성 합성 기술은 네오사피엔스만의 경쟁력”이라고 하며 “타입캐스트 서비스는 앞서 말한 경쟁력을 바탕으로 미디어, 엔터테인먼트 등 다양한 분야에 폭넓게 진출해 혁신을 주도할 것”이라고 설명했다. 현재 인공지능 성우 서비스 ‘타입캐스트’를 운영하며 다큐멘터리 등 방송, 영상 더빙, 뉴스 제작, 오디오 북 교육 콘텐츠 등 다양한 분야의 사업을 진행 중이다.
#
#   [링크 텍스트](https://platum.kr/archives/141751)
# *   **언어** - 이메일 번역 서비스 ‘헤이버니’
#
#      : 외국어로 써야 하는 비즈니스 이메일에 대한 직장인들의 스트레스를 해결하기 위해 등장하였다. 번역이 필요한 이메일을 준비한 우 헤이버니에 이메일을 보내면 10초도 안 되어 영어로 번역된 이메일이 돌아온다. 사전을 검토하며 웹 번역기를 사용한 것보다 번역이 매끄럽다. 따로 앱을 다운로드하거나 회원가입을 할 필요도 없다. 또한 번역을 거쳐도 이메일 안에 표나 글자 크기 등 양식(스타일)이 유지된다는 장점이 있다. 관계자는 이메일에 많이 쓰는 표현 1만 2000개를 학습시킨 것이 자연스러운 번역의 핵심이라고 설명했으며, 이메일의 보안 이슈와 관련해서는 “인공지능 기반 번역으로 사람이 전혀 관여하지 않기에 비밀스러운 내용이 담긴 이메일도 철저히 보안이 가능하다”고 밝혔다.
#
#      [링크 텍스트](https://news.joins.com/article/23748213)
# *   **이미지** - 환자의 얼굴 사진만으로 피부암을 검출 및 진단
#
#     : 그동안 ai를 활용하여 피부암 진단 연구가 활발히 진행되고 있었으나 보통 ai가 환자의 전체 사진에서 병변 부위만을 잘라놓은 사진을 보고 피부암 여부를 구분하는데 그쳤고, 피부과 전문의들이 ai에 암으로 의심되는 병변을 일일이 지목해야 됐고, 피부암과 전혀 무관한 염증성병변이나 정상 구조물에 대해 양성으로 진단하는 문제가 발생하여 ai가 실제 의료현장에서 사용되기 힘들었다. 이번 연구의 성공에 따라 ai가 증명사진과 같은 환자의 얼굴 사진에서 안면구조를 인식해 암의 위치를 자동으로 찾아내는 진단기술이 의료현장에서 조만간 사용될 수 있게 됐다. 연구에서 사용된 ai 기술은 ‘합성곱신경망(CNN)’으로 인간의 망막 구조와 유사한 신경망 알고리즘으로 현재 시각분야 연구에서 사물을 분류하는데 사용하하고 있다.
#
#     [링크 텍스트](https://www.hankookilbo.com/News/Read/202005041040060726)
# *   **자율주행** - 제주공항에서 쏘카 차량을 인수하러 갈 때 운영되는 자율주행 셔틀
#
#     : 제주 공항에 도착한 여행자가 공유차량을 인수하기 위해 ‘쏘카 스테이션’으로 이동하는데, 왕복 5km의 이 구간을 자율주행 셔틀이 오간다. 이는 교통을 통제하는 시범 운행이 아닌, 실제 도로에서 일반인 승객들이 이용하는 것으로 자율 주행 셔틀에는 승객 2인이 탑승할 수 있다. 현재 ‘운전자 없는 자율주행’은 국내법상 아직 불가능하므로 셔틀에는 교육을 받은 전문 인력이 동승하며, 탑승 신청은 QR코드로 접속해 할 수 있다. 회사측에 따르면,  지난 6개월간 교차로, 횡단보도, 신호등, 이면도로 등이 포함된 해당 구간에서 1600여 회 이상, 8000여 분 이상의 주행 실험을 거쳤다고 한다.
#
#     [링크 텍스트](https://news.joins.com/article/23779310)
